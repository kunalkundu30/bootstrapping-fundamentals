# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
sample
# Out:
# array([-0.16130914, -0.46949053, -0.24968977,  0.92193982, -0.65934745,
#        -2.53349141,  1.80322107, -0.70649632,  1.22133106, -0.2815151 ,
#         1.49920994, -0.90974916, -0.97054218,  0.20823417,  0.16312135,
#        -0.17458884, -0.1825392 , -0.25345071,  0.88320519,  1.71549935,
#        -0.08800707,  1.19854271, -0.17015738,  0.16376225,  0.99676305,
#        -0.24247831, -1.56243334, -0.94945169, -0.1072539 , -0.76741844])

# %%
no_of_samples = 30
result={}
for sample_size in range(1,no_of_samples+1):
    sample = np.random.normal(loc=0,scale=1,size=sample_size)
    sample_mean = sample.mean()
    sample_std_dev = np.sqrt(np.var(sample,ddof=1))
    result[sample_size] = [sample_mean, sample_std_dev]
    # print("Mean :", sample.mean())
    # print("Standard Deviation :", sample.std())

means = [sample_result[0] for sample_result in result.values()]
std_devs = [sample_result[1] for sample_result in result.values()]
sample_sizes = result.keys()

plt.plot(sample_sizes, means)
plt.xlabel("Sample size")
plt.ylabel("Sample Mean")
plt.title("Variation of Sample mean with Sample size")
# Out:
# Text(0, 0.5, 'Sample Mean')

# %%
[i[0] for i in result.values()]
# Out:
# [-1.304644924561261,
#  -0.2349563532792352,
#  -0.20914875300276803,
#  -0.5274896763774038,
#  -0.1934367819235306,
#  0.011263187993510579,
#  0.15234019370984533,
#  -0.29782244077685754,
#  -0.3841574752590153,
#  0.028596829338553342,
#  0.2402913780216595,
#  0.039355621662232894,
#  -0.03897277414433552,
#  -0.16691170879159306,
#  -0.5527776633687754,
#  -0.13230570782210035,
#  0.28398521954062916,
#  -0.23894317433443618,
#  -0.08034747756231693,
#  -0.1561459114359119,
#  0.13024861199006924,
#  -0.12331577859475683,
#  -0.02056659553805216,
#  -0.13334740130102551,
#  0.08199340632827308,
#  0.22900156549932274,
#  -0.16197388304694613,
#  -0.0638023349767819,
#  -0.025549564584698516,
#  0.0006733862096261386]
